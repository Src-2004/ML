# %% [markdown]
# #**In this line we just upload files in google colab **

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-e777d8e9-4920-44c6-b073-141d80d4934f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e777d8e9-4920-44c6-b073-141d80d4934f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #**In** **this** **line** **we** **import** **the** **libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**in** **this** **line** **we** **ue** **the** **CSV** **for** **read** **the** **files**

# %%
employe_salary=pd.read_csv('Employee_Salary.csv')

# %% [markdown]
# #**in** **this** **line** **we** **just** **read** **the** **file**

# %%
employe_salary
# Out:
#       Years of Experience        Salary
# 0                1.000000   40000.00000
# 1                2.257942   65979.42119
# 2                2.450875   67253.57549
# 3                2.498713   67342.43510
# 4                2.613729   70532.20448
# ...                   ...           ...
# 1995            19.178575  421534.69100
# 1996            19.254499  430478.02650
# 1997            19.353369  438090.84540
# 1998            19.842520  482242.16080
# 1999            20.000000  500000.00000
#
# [2000 rows x 2 columns]

# %% [markdown]
# #**in** **this** **line** **we** **use** **HEAD** **for** **first** **five** **rows**

# %%
employe_salary.head()
# Out:
#    Years of Experience       Salary
# 0             1.000000  40000.00000
# 1             2.257942  65979.42119
# 2             2.450875  67253.57549
# 3             2.498713  67342.43510
# 4             2.613729  70532.20448

# %% [markdown]
# #**in** **this** **line** **we** **use** **TAIL** **for** **last** **five** **rows**

# %%
employe_salary.tail()
# Out:
#       Years of Experience       Salary
# 1995            19.178575  421534.6910
# 1996            19.254499  430478.0265
# 1997            19.353369  438090.8454
# 1998            19.842520  482242.1608
# 1999            20.000000  500000.0000

# %% [markdown]
# #Use seaborn to create a jointplot to compare the time salary gained by years of experience

# %%
sns.set_palette("GnBu_d")
sns.set_style("whitegrid")

# %% [markdown]
# #how much salary increase by years of experience

# %%
sns.jointplot(x='Years of Experience',y='Salary',data=employe_salary)

# %% [markdown]
# #now for good looking we use hax

# %%
sns.jointplot(x='Years of Experience',y='Salary',data=employe_salary,kind='hex')

# %% [markdown]
# #in this we are exploring all the relations in this entire deta by using pairplot

# %%
sns.pairplot(employe_salary)

# %% [markdown]
# #in this we create a linear model plot by usung seaborn to know the salary vs ecperince

# %%
sns.lmplot(x='Years of Experience',y='Salary',data=employe_salary)

# %% [markdown]
# #**now we devide the two rows in to two parts as X and y for testing the data **

# %%
X=employe_salary[['Years of Experience']]
y=employe_salary['Salary']

# %% [markdown]
# #**in this line we are going to train both veriable X and y **

# %%
X_train=X
y_train=y

# %% [markdown]
# #**in this line we are just display the X variable **

# %%
X
# Out:
#       Years of Experience
# 0                1.000000
# 1                2.257942
# 2                2.450875
# 3                2.498713
# 4                2.613729
# ...                   ...
# 1995            19.178575
# 1996            19.254499
# 1997            19.353369
# 1998            19.842520
# 1999            20.000000
#
# [2000 rows x 1 columns]

# %% [markdown]
# #**in this line we are going to display the y variable **

# %%
y
# Out:
# 0        40000.00000
# 1        65979.42119
# 2        67253.57549
# 3        67342.43510
# 4        70532.20448
#             ...
# 1995    421534.69100
# 1996    430478.02650
# 1997    438090.84540
# 1998    482242.16080
# 1999    500000.00000
# Name: Salary, Length: 2000, dtype: float64

# %% [markdown]
# #**now we import the regression **

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #**in this line we calculate the intercept in mathe matical equation y=mx+b**

# %%
regression=LinearRegression(fit_intercept=True)

# %% [markdown]
# #**Calculates the coefficients (m) and intercept (b) for the linear regression **
# #**equation y=mX+b **

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #**regression.coef means the cofficient of the features in the linear regresion y=m1x1+m2x2+...b**
# #**it predict the y-value when all features (x1,x2,..)are 0**

# %%
print('Linear Model Coefficient (m):',regression.coef_)
print('Linear Model Intercept (b):',regression.intercept_)
# Out:
# Linear Model Coefficient (m): [11640.22916165]
# Linear Model Intercept (b): -13063.099315186948

# %% [markdown]
# # **in this line we just check the information of the giving file **

# %%
employe_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Years of Experience  2000 non-null   float64
#  1   Salary               2000 non-null   float64
# dtypes: float64(2)
# memory usage: 31.4 KB

# %% [markdown]
# #**in this line we are just describe the givin files **

# %%
employe_salary.describe()
# Out:
#        Years of Experience         Salary
# count          2000.000000    2000.000000
# mean             10.739095  111942.422469
# std               2.989853   45055.817085
# min               1.000000   40000.000000
# 25%               8.812255   87938.130895
# 50%              10.738822   93376.356875
# 75%              12.785483  116978.641550
# max              20.000000  500000.000000

# %% [markdown]
# #**PolynomialFeatures(degree=2):**
# #**Expands the input features into a higher-dimensional space by adding polynomial combinations up to the specified degree.**
# #**This is useful for modeling non-linear relationships.**
# #**poly_regression:**
# #**Stores the instance of PolynomialFeatures with degree 2.**
# #**Can be used to transform data for polynomial regression.**

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regression=PolynomialFeatures(degree=2)

# %% [markdown]
# #**The statement X_columns = poly_regression.fit_transform(X_train) transforms the input features to a new set of polynomial features**

# %%
X_colums=poly_regression.fit_transform(X_train)

# %% [markdown]
# #**in this line we are just print the coloums **

# %%
print(X_colums)
# Out:
# [[  1.           1.           1.        ]
#  [  1.           2.25794198   5.09830199]
#  [  1.           2.45087546   6.00679053]
#  ...
#  [  1.          19.35336879 374.55288352]
#  [  1.          19.84251968 393.72558725]
#  [  1.          20.         400.        ]]

# %% [markdown]
# #**as we can see the deta was incorrect because employe cannot get the negetive salary**

# %% [markdown]
# #**so the given result we found out the given data was incorrect **
